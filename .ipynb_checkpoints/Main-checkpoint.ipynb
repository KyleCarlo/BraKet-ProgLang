# %%
# !antlr4 -Dlanguage=Python3 BraKet.g4 -visitor -no-listener

# %%
import sys
from antlr4 import *
from BraKetLexer import BraKetLexer
from BraKetParser import BraKetParser
from antlr4.error.ErrorListener import ErrorListener

class CollectingErrorListener(ErrorListener):
    def __init__(self):
        self.errors = []

    def syntaxError(self, recognizer, offendingSymbol, line, column, msg, e):
        self.errors.append(
            f"line {line}:{column} {msg}"
        )

def main(show_tokens=True, code="", file_dump=False):
    input_stream = InputStream(code)

    # 2. Lexical Analysis
    lexer = BraKetLexer(input_stream)
    lexer.removeErrorListeners()
    lex_errors = CollectingErrorListener()
    lexer.addErrorListener(lex_errors)

    token_stream = CommonTokenStream(lexer)

    # 3. Parsing
    parser = BraKetParser(token_stream)
    parser.removeErrorListeners()
    parse_errors = CollectingErrorListener()
    parser.addErrorListener(parse_errors)

def main(show_tokens=True, code="", file_dump=False):
    # 1. Provide the input
    input_stream = InputStream(code)

    # 2. Lexical Analysis
    lexer = BraKetLexer(input_stream)
    lexer.removeErrorListeners()
    lex_errors = CollectingErrorListener()
    lexer.addErrorListener(lex_errors)
    token_stream = CommonTokenStream(lexer)

    # 3. Parsing
    parser = BraKetParser(token_stream)
    parser.removeErrorListeners()
    parse_errors = CollectingErrorListener()
    parser.addErrorListener(parse_errors)
    tree = parser.program()  # Ensure 'prog' matches your .g4 start rule

    # 4. Print the Tree
    print("--- Parse Tree ---")
    str_tree = tree.toStringTree(recog=parser)
    if file_dump:
        with open('ast.txt', mode='w', encoding='utf-8') as file:
            file.write(str_tree)
            print('AST saved to ast.txt.')
    else:
        print(str_tree)

    # 5. Output Tokens (Optional)
    if show_tokens:
        print("\n--- Tokens ---")
        # We fill the stream to ensure all tokens are loaded
        token_stream.fill

        if file_dump:
            with open('tokens.txt', mode='w', encoding='utf-8') as file:
                file.write(f"{'INDEX':<6} | {'TEXT':<10} | {'TYPE':<15} | {'LINE':<5} | {'COL':<5}\n")
                file.write(f"{'-' * 50}\n")
                for i, token in enumerate(token_stream.tokens):
                    # Map the integer type ID to the name you defined in the .g4 file
                    t_type = BraKetParser.symbolicNames[token.type] if token.type != -1 else "EOF"
                    
                    file.write(f"{i:<6} | {token.text:<10} | {t_type:<15} | {token.line:<5} | {token.column:<5}\n")
                print('Tokens saved to tokens.txt.')
        else:        
            print(f"{'INDEX':<6} | {'TEXT':<10} | {'TYPE':<15} | {'LINE':<5} | {'COL':<5}")
            print("-" * 50)
            
            for i, token in enumerate(token_stream.tokens):
                # Map the integer type ID to the name you defined in the .g4 file
                t_type = BraKetParser.symbolicNames[token.type] if token.type != -1 else "EOF"
                
                print(f"{i:<6} | {token.text:<10} | {t_type:<15} | {token.line:<5} | {token.column:<5}")

    # 6. Print Errors (after tokens)
    print("\n--- Errors ---")
    if file_dump:
        with open('errors.txt', mode='w', encoding='utf-8') as file:
            if lex_errors.errors or parse_errors.errors:        
                if lex_errors.errors:
                    file.write("Lexer Errors:\n")
                    for err in lex_errors.errors:
                        file.write(f"  {err}\n")
                    file.write("\n")
        
                if parse_errors.errors:
                    file.write("Parser Errors:\n")
                    for err in parse_errors.errors:
                        file.write(f"  {err}\n")
            else:
                file.write("--- Errors ---\n")
                file.write("No errors.")
        print("Errors saved to errors.txt.")
    else:
        if lex_errors.errors or parse_errors.errors:    
            if lex_errors.errors:
                print("Lexer Errors:")
                for err in lex_errors.errors:
                    print("  " + err)
    
            if parse_errors.errors:
                print("Parser Errors:")
                for err in parse_errors.errors:
                    print("  " + err)
        else:
            print("No errors.")

if __name__ == '__main__':
    main()
# Out:
# --- Parse Tree ---
# program
#
# --- Tokens ---
# INDEX  | TEXT       | TYPE            | LINE  | COL
# --------------------------------------------------
# 0      | <EOF>      | EOF             | 1     | 0
#
# --- Errors ---
# No errors.

# %%
code='''
from _file1_ import _, test, test
from test import test
import filename

const i = 0
const x = t+(-1+9i)
const arr = [x, i, 1+1i, 1+0i]
const |t> = (1,1i)
const <t0| = (0,1) @ (0,1)
const not_op = (|t>)
const op = ((1i, 2), (1i, 2))
const booltest = !1 > (2 < 2) || (3 && 0) == 1

func test_function () {}

func test2 () {}
'''

# %%
main(code=code, file_dump=False)
# Out:
# --- Parse Tree ---
# (program (import_list (import_statement from _file1_ import (func_list _ , test , test)) (import_statement from test import (func_list test)) (import_statement import filename)) (const_decl_list (const_decl const (var_decl i = (expression (num_expression (num_term (num_factor 0)))))) (const_decl const (var_decl x = (expression (num_expression (num_term (num_factor (dirac_expression t))) + (num_expression (num_term (num_factor ( (num_expression (num_term (num_factor -1+9i))) )))))))) (const_decl const (var_decl arr = (expression (array [ (expression x) , (expression i) , (expression (num_expression (num_term (num_factor 1)) + (num_expression (num_term (num_factor 1i))))) , (expression (num_expression (num_term (num_factor 1)) + (num_expression (num_term (num_factor 0i))))) ])))) (const_decl const (var_decl |t> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 1) , (braket_value 1i) )))))))) (const_decl const (var_decl <t0| = (num_expression (num_term (num_factor (dirac_expression (dirac_expression (braket_vector ( (braket_value 0) , (braket_value 1) ))) @ (dirac_expression (braket_vector ( (braket_value 0) , (braket_value 1) ))))))))) (const_decl const (var_decl not_op = (expression (num_expression (num_term (num_factor ( (num_expression (num_term (num_factor (dirac_expression |t>)))) ))))))) (const_decl const (var_decl op = (expression (num_expression (num_term (num_factor (dirac_expression (op ( (braket_vector ( (braket_value 1i) , (braket_value 2) )) , (braket_vector ( (braket_value 1i) , (braket_value 2) )) ))))))))) (const_decl const (var_decl booltest = (expression (bool_expression (bool_or (bool_and (bool_cmp (bool_unary ! (bool_unary (bool_primary 1))))))))))))
#
# --- Tokens ---
# INDEX  | TEXT       | TYPE            | LINE  | COL
# --------------------------------------------------
# 0      | from       | FROM            | 2     | 0
# 1      | _file1_    | IDENTIFIER      | 2     | 5
# 2      | import     | IMPORT          | 2     | 13
# 3      | _          | IDENTIFIER      | 2     | 20
# 4      | ,          | COMMA           | 2     | 21
# 5      | test       | IDENTIFIER      | 2     | 23
# 6      | ,          | COMMA           | 2     | 27
# 7      | test       | IDENTIFIER      | 2     | 29
# 8      | from       | FROM            | 3     | 0
# 9      | test       | IDENTIFIER      | 3     | 5
# 10     | import     | IMPORT          | 3     | 10
# 11     | test       | IDENTIFIER      | 3     | 17
# 12     | import     | IMPORT          | 4     | 0
# 13     | filename   | IDENTIFIER      | 4     | 7
# 14     | const      | CONST           | 6     | 0
# 15     | i          | IDENTIFIER      | 6     | 6
# 16     | =          | ASSIGN          | 6     | 8
# 17     | 0          | INT             | 6     | 10
# 18     | const      | CONST           | 7     | 0
# 19     | x          | IDENTIFIER      | 7     | 6
# 20     | =          | ASSIGN          | 7     | 8
# 21     | t          | IDENTIFIER      | 7     | 10
# 22     | +          | ADD             | 7     | 11
# 23     | (          | LPAREN          | 7     | 12
# 24     | -1+9i      | COMPLEX         | 7     | 13
# 25     | )          | RPAREN          | 7     | 18
# 26     | const      | CONST           | 8     | 0
# 27     | arr        | IDENTIFIER      | 8     | 6
# 28     | =          | ASSIGN          | 8     | 10
# 29     | [          | LSQUARE         | 8     | 12
# 30     | x          | IDENTIFIER      | 8     | 13
# 31     | ,          | COMMA           | 8     | 14
# 32     | i          | IDENTIFIER      | 8     | 16
# 33     | ,          | COMMA           | 8     | 17
# 34     | 1          | INT             | 8     | 19
# 35     | +          | ADD             | 8     | 20
# 36     | 1i         | COMPLEX         | 8     | 21
# 37     | ,          | COMMA           | 8     | 23
# 38     | 1          | INT             | 8     | 25
# 39     | +          | ADD             | 8     | 26
# 40     | 0i         | COMPLEX         | 8     | 27
# 41     | ]          | RSQUARE         | 8     | 29
# 42     | const      | CONST           | 9     | 0
# 43     | |t>        | KET_IDENTIFIER  | 9     | 6
# 44     | =          | ASSIGN          | 9     | 10
# 45     | (          | LPAREN          | 9     | 12
# 46     | 1          | INT             | 9     | 13
# 47     | ,          | COMMA           | 9     | 14
# 48     | 1i         | COMPLEX         | 9     | 15
# 49     | )          | RPAREN          | 9     | 17
# 50     | const      | CONST           | 10    | 0
# 51     | <t0|       | BRA_IDENTIFIER  | 10    | 6
# 52     | =          | ASSIGN          | 10    | 11
# 53     | (          | LPAREN          | 10    | 13
# 54     | 0          | INT             | 10    | 14
# 55     | ,          | COMMA           | 10    | 15
# 56     | 1          | INT             | 10    | 16
# 57     | )          | RPAREN          | 10    | 17
# 58     | @          | TENSOR          | 10    | 19
# 59     | (          | LPAREN          | 10    | 21
# 60     | 0          | INT             | 10    | 22
# 61     | ,          | COMMA           | 10    | 23
# 62     | 1          | INT             | 10    | 24
# 63     | )          | RPAREN          | 10    | 25
# 64     | const      | CONST           | 11    | 0
# 65     | not_op     | IDENTIFIER      | 11    | 6
# 66     | =          | ASSIGN          | 11    | 13
# 67     | (          | LPAREN          | 11    | 15
# 68     | |t>        | KET_IDENTIFIER  | 11    | 16
# 69     | )          | RPAREN          | 11    | 19
# 70     | const      | CONST           | 12    | 0
# 71     | op         | IDENTIFIER      | 12    | 6
# 72     | =          | ASSIGN          | 12    | 9
# 73     | (          | LPAREN          | 12    | 11
# 74     | (          | LPAREN          | 12    | 12
# 75     | 1i         | COMPLEX         | 12    | 13
# 76     | ,          | COMMA           | 12    | 15
# 77     | 2          | INT             | 12    | 17
# 78     | )          | RPAREN          | 12    | 18
# 79     | ,          | COMMA           | 12    | 19
# 80     | (          | LPAREN          | 12    | 21
# 81     | 1i         | COMPLEX         | 12    | 22
# 82     | ,          | COMMA           | 12    | 24
# 83     | 2          | INT             | 12    | 26
# 84     | )          | RPAREN          | 12    | 27
# 85     | )          | RPAREN          | 12    | 28
# 86     | const      | CONST           | 13    | 0
# 87     | booltest   | IDENTIFIER      | 13    | 6
# 88     | =          | ASSIGN          | 13    | 15
# 89     | !          | NEG             | 13    | 17
# 90     | 1          | INT             | 13    | 18
# 91     | >          | GT              | 13    | 20
#
# --- Errors ---
# No errors.

# %%
code='''
func testfunc() {
    return 8
}
func test2(x, y=1, x=2) {
|_0> = (1,0)
if ( x == 0 ) {
test = 1
} elif ( x == 1 ) {
test = 2
} elif ( x == 2 ) {
test = testfunc()
} else {
return |_0>*<_0|
} 
}
main() {}
'''

# %%
main(code=code, file_dump=False)
# Out:
# --- Parse Tree ---
# (program (func_decl_list (func_decl func testfunc ( ) { (statement_list (statement (return_statement return (expression (num_expression (num_term (num_factor 8))))))) }) (func_decl func test2 ( (param_list (identifier_list x) , (default_list (assign_statement (var_decl y = (expression (num_expression (num_term (num_factor 1)))))) , (assign_statement (var_decl x = (expression (num_expression (num_term (num_factor 2)))))))) ) { (statement_list (statement (assign_statement (var_decl |_0> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 1) , (braket_value 0) ))))))))) (statement (if_statement if ( (bool_expression (bool_or (bool_and (bool_cmp (num_expression (num_term (num_factor (dirac_expression x)))) (num_comp (eq_comp ==)) (num_expression (num_term (num_factor 0))))))) ) { (statement_list (statement (assign_statement (var_decl test = (expression (num_expression (num_term (num_factor 1)))))))) } (elif elif ( (bool_expression (bool_or (bool_and (bool_cmp (num_expression (num_term (num_factor (dirac_expression x)))) (num_comp (eq_comp ==)) (num_expression (num_term (num_factor 1))))))) ) { (statement_list (statement (assign_statement (var_decl test = (expression (num_expression (num_term (num_factor 2)))))))) }) (elif elif ( (bool_expression (bool_or (bool_and (bool_cmp (num_expression (num_term (num_factor (dirac_expression x)))) (num_comp (eq_comp ==)) (num_expression (num_term (num_factor 2))))))) ) { (statement_list (statement (assign_statement (var_decl test = (expression (func_call_statement testfunc ( ))))))) }) (else else { (statement_list (statement (return_statement return (expression (num_expression (num_term (num_factor (dirac_expression |_0>)) * (num_term (num_factor (dirac_expression <_0|))))))))) })))) })) (main_function main ( ) { }))
#
# --- Tokens ---
# INDEX  | TEXT       | TYPE            | LINE  | COL
# --------------------------------------------------
# 0      | func       | FUNC            | 2     | 0
# 1      | testfunc   | IDENTIFIER      | 2     | 5
# 2      | (          | LPAREN          | 2     | 13
# 3      | )          | RPAREN          | 2     | 14
# 4      | {          | LCURLY          | 2     | 16
# 5      | return     | RETURN          | 3     | 4
# 6      | 8          | INT             | 3     | 11
# 7      | }          | RCURLY          | 4     | 0
# 8      | func       | FUNC            | 5     | 0
# 9      | test2      | IDENTIFIER      | 5     | 5
# 10     | (          | LPAREN          | 5     | 10
# 11     | x          | IDENTIFIER      | 5     | 11
# 12     | ,          | COMMA           | 5     | 12
# 13     | y          | IDENTIFIER      | 5     | 14
# 14     | =          | ASSIGN          | 5     | 15
# 15     | 1          | INT             | 5     | 16
# 16     | ,          | COMMA           | 5     | 17
# 17     | x          | IDENTIFIER      | 5     | 19
# 18     | =          | ASSIGN          | 5     | 20
# 19     | 2          | INT             | 5     | 21
# 20     | )          | RPAREN          | 5     | 22
# 21     | {          | LCURLY          | 5     | 24
# 22     | |_0>       | KET_IDENTIFIER  | 6     | 0
# 23     | =          | ASSIGN          | 6     | 5
# 24     | (          | LPAREN          | 6     | 7
# 25     | 1          | INT             | 6     | 8
# 26     | ,          | COMMA           | 6     | 9
# 27     | 0          | INT             | 6     | 10
# 28     | )          | RPAREN          | 6     | 11
# 29     | if         | IF              | 7     | 0
# 30     | (          | LPAREN          | 7     | 3
# 31     | x          | IDENTIFIER      | 7     | 5
# 32     | ==         | EQ              | 7     | 7
# 33     | 0          | INT             | 7     | 10
# 34     | )          | RPAREN          | 7     | 12
# 35     | {          | LCURLY          | 7     | 14
# 36     | test       | IDENTIFIER      | 8     | 0
# 37     | =          | ASSIGN          | 8     | 5
# 38     | 1          | INT             | 8     | 7
# 39     | }          | RCURLY          | 9     | 0
# 40     | elif       | ELIF            | 9     | 2
# 41     | (          | LPAREN          | 9     | 7
# 42     | x          | IDENTIFIER      | 9     | 9
# 43     | ==         | EQ              | 9     | 11
# 44     | 1          | INT             | 9     | 14
# 45     | )          | RPAREN          | 9     | 16
# 46     | {          | LCURLY          | 9     | 18
# 47     | test       | IDENTIFIER      | 10    | 0
# 48     | =          | ASSIGN          | 10    | 5
# 49     | 2          | INT             | 10    | 7
# 50     | }          | RCURLY          | 11    | 0
# 51     | elif       | ELIF            | 11    | 2
# 52     | (          | LPAREN          | 11    | 7
# 53     | x          | IDENTIFIER      | 11    | 9
# 54     | ==         | EQ              | 11    | 11
# 55     | 2          | INT             | 11    | 14
# 56     | )          | RPAREN          | 11    | 16
# 57     | {          | LCURLY          | 11    | 18
# 58     | test       | IDENTIFIER      | 12    | 0
# 59     | =          | ASSIGN          | 12    | 5
# 60     | testfunc   | IDENTIFIER      | 12    | 7
# 61     | (          | LPAREN          | 12    | 15
# 62     | )          | RPAREN          | 12    | 16
# 63     | }          | RCURLY          | 13    | 0
# 64     | else       | ELSE            | 13    | 2
# 65     | {          | LCURLY          | 13    | 7
# 66     | return     | RETURN          | 14    | 0
# 67     | |_0>       | KET_IDENTIFIER  | 14    | 7
# 68     | *          | MUL             | 14    | 11
# 69     | <_0|       | BRA_IDENTIFIER  | 14    | 12
# 70     | }          | RCURLY          | 15    | 0
# 71     | }          | RCURLY          | 16    | 0
# 72     | main       | MAIN            | 17    | 0
# 73     | (          | LPAREN          | 17    | 4
# 74     | )          | RPAREN          | 17    | 5
# 75     | {          | LCURLY          | 17    | 7
# 76     | }          | RCURLY          | 17    | 8
# 77     | <EOF>      | EOF             | 18    | 0
#
# --- Errors ---
# No errors.

# %%
code='''
main() {
    x = ''
    y = "test string

    print(x, y)
}
'''

# %%
main(code=code, file_dump=False)
# Out:
# --- Parse Tree ---
# (program (main_function main ( ) { (statement_list (statement (assign_statement (var_decl x = (expression (num_expression (num_term (num_factor ''))))))) (statement (assign_statement (var_decl y = expression)))) <missing '}'>))
#
# --- Tokens ---
# INDEX  | TEXT       | TYPE            | LINE  | COL
# --------------------------------------------------
# 0      | main       | MAIN            | 2     | 0
# 1      | (          | LPAREN          | 2     | 4
# 2      | )          | RPAREN          | 2     | 5
# 3      | {          | LCURLY          | 2     | 7
# 4      | x          | IDENTIFIER      | 3     | 4
# 5      | =          | ASSIGN          | 3     | 6
# 6      | ''         | CHAR            | 3     | 8
# 7      | y          | IDENTIFIER      | 4     | 4
# 8      | =          | ASSIGN          | 4     | 6
# 9      | <EOF>      | EOF             | 8     | 0
#
# --- Errors ---
# Lexer Errors:
#   line 4:8 token recognition error at: '"test string\n\n    print(x, y)\n}\n'
# Parser Errors:
#   line 8:0 mismatched input '<EOF>' expecting {KET_IDENTIFIER, BRA_IDENTIFIER, INT, FLOAT, CHAR, STRING, COMPLEX, 'true', 'false', '+', '-', '!', '(', '[', '{', IDENTIFIER}

# %%
code='''
const _0 = {
 x=0,
 func test() {
     print(x)
 },
 y=1
}
func testFun(struct) {
    print(struct.x)
}
main() {
    struct_test2 = {
        x = 1,
        y = 1,
        func test() {
            print(y, x)
        }
    }
    array = [[0], [1], [2]]
    testFun(struct_test2)
}
'''

# %%
main(code=code, file_dump=False)
# Out:
# --- Parse Tree ---
# (program (const_decl_list (const_decl const (var_decl _0 = (expression (struct { (struct_value (var_decl x = (expression (num_expression (num_term (num_factor 0))))) , (struct_value (func_decl func test ( ) { (statement_list (statement (func_call_statement print ( (arg_list (arg x)) )))) }) , (struct_value (var_decl y = (expression (num_expression (num_term (num_factor 1)))))))) }))))) (func_decl_list (func_decl func testFun ( (param_list (identifier_list struct)) ) { (statement_list (statement (func_call_statement print ( (arg_list (arg (struct_access struct . x))) )))) })) (main_function main ( ) { (statement_list (statement (assign_statement (var_decl struct_test2 = (expression (struct { (struct_value (var_decl x = (expression (num_expression (num_term (num_factor 1))))) , (struct_value (var_decl y = (expression (num_expression (num_term (num_factor 1))))) , (struct_value (func_decl func test ( ) { (statement_list (statement (func_call_statement print ( (arg_list (arg y) , (arg_list (arg x))) )))) })))) }))))) (statement (assign_statement (var_decl array = (expression (array [ (expression (array [ (expression (num_expression (num_term (num_factor 0)))) ])) , (expression (array [ (expression (num_expression (num_term (num_factor 1)))) ])) , (expression (array [ (expression (num_expression (num_term (num_factor 2)))) ])) ]))))) (statement (func_call_statement testFun ( (arg_list (arg struct_test2)) )))) }))
#
# --- Tokens ---
# INDEX  | TEXT       | TYPE            | LINE  | COL
# --------------------------------------------------
# 0      | const      | CONST           | 2     | 0
# 1      | _0         | IDENTIFIER      | 2     | 6
# 2      | =          | ASSIGN          | 2     | 9
# 3      | {          | LCURLY          | 2     | 11
# 4      | x          | IDENTIFIER      | 3     | 1
# 5      | =          | ASSIGN          | 3     | 2
# 6      | 0          | INT             | 3     | 3
# 7      | ,          | COMMA           | 3     | 4
# 8      | func       | FUNC            | 4     | 1
# 9      | test       | IDENTIFIER      | 4     | 6
# 10     | (          | LPAREN          | 4     | 10
# 11     | )          | RPAREN          | 4     | 11
# 12     | {          | LCURLY          | 4     | 13
# 13     | print      | IDENTIFIER      | 5     | 5
# 14     | (          | LPAREN          | 5     | 10
# 15     | x          | IDENTIFIER      | 5     | 11
# 16     | )          | RPAREN          | 5     | 12
# 17     | }          | RCURLY          | 6     | 1
# 18     | ,          | COMMA           | 6     | 2
# 19     | y          | IDENTIFIER      | 7     | 1
# 20     | =          | ASSIGN          | 7     | 2
# 21     | 1          | INT             | 7     | 3
# 22     | }          | RCURLY          | 8     | 0
# 23     | func       | FUNC            | 9     | 0
# 24     | testFun    | IDENTIFIER      | 9     | 5
# 25     | (          | LPAREN          | 9     | 12
# 26     | struct     | IDENTIFIER      | 9     | 13
# 27     | )          | RPAREN          | 9     | 19
# 28     | {          | LCURLY          | 9     | 21
# 29     | print      | IDENTIFIER      | 10    | 4
# 30     | (          | LPAREN          | 10    | 9
# 31     | struct     | IDENTIFIER      | 10    | 10
# 32     | .          | DOT             | 10    | 16
# 33     | x          | IDENTIFIER      | 10    | 17
# 34     | )          | RPAREN          | 10    | 18
# 35     | }          | RCURLY          | 11    | 0
# 36     | main       | MAIN            | 12    | 0
# 37     | (          | LPAREN          | 12    | 4
# 38     | )          | RPAREN          | 12    | 5
# 39     | {          | LCURLY          | 12    | 7
# 40     | struct_test2 | IDENTIFIER      | 13    | 4
# 41     | =          | ASSIGN          | 13    | 17
# 42     | {          | LCURLY          | 13    | 19
# 43     | x          | IDENTIFIER      | 14    | 8
# 44     | =          | ASSIGN          | 14    | 10
# 45     | 1          | INT             | 14    | 12
# 46     | ,          | COMMA           | 14    | 13
# 47     | y          | IDENTIFIER      | 15    | 8
# 48     | =          | ASSIGN          | 15    | 10
# 49     | 1          | INT             | 15    | 12
# 50     | ,          | COMMA           | 15    | 13
# 51     | func       | FUNC            | 16    | 8
# 52     | test       | IDENTIFIER      | 16    | 13
# 53     | (          | LPAREN          | 16    | 17
# 54     | )          | RPAREN          | 16    | 18
# 55     | {          | LCURLY          | 16    | 20
# 56     | print      | IDENTIFIER      | 17    | 12
# 57     | (          | LPAREN          | 17    | 17
# 58     | y          | IDENTIFIER      | 17    | 18
# 59     | ,          | COMMA           | 17    | 19
# 60     | x          | IDENTIFIER      | 17    | 21
# 61     | )          | RPAREN          | 17    | 22
# 62     | }          | RCURLY          | 18    | 8
# 63     | }          | RCURLY          | 19    | 4
# 64     | array      | IDENTIFIER      | 20    | 4
# 65     | =          | ASSIGN          | 20    | 10
# 66     | [          | LSQUARE         | 20    | 12
# 67     | [          | LSQUARE         | 20    | 13
# 68     | 0          | INT             | 20    | 14
# 69     | ]          | RSQUARE         | 20    | 15
# 70     | ,          | COMMA           | 20    | 16
# 71     | [          | LSQUARE         | 20    | 18
# 72     | 1          | INT             | 20    | 19
# 73     | ]          | RSQUARE         | 20    | 20
# 74     | ,          | COMMA           | 20    | 21
# 75     | [          | LSQUARE         | 20    | 23
# 76     | 2          | INT             | 20    | 24
# 77     | ]          | RSQUARE         | 20    | 25
# 78     | ]          | RSQUARE         | 20    | 26
# 79     | testFun    | IDENTIFIER      | 21    | 4
# 80     | (          | LPAREN          | 21    | 11
# 81     | struct_test2 | IDENTIFIER      | 21    | 12
# 82     | )          | RPAREN          | 21    | 24
# 83     | }          | RCURLY          | 22    | 0
# 84     | <EOF>      | EOF             | 23    | 0
#
# --- Errors ---
# No errors.

# %%
code='''
const |ket0> = (1,0)
const |ket1> = (0,1)
const op = ((1,0), (0,1))
const op2 = 1/2 * ((1i,1i), (1i,1i)) 

main() {
    x = <ket1|@<ket1|*|ket0>@|ket0>
    y = ((1 < 2) || true) && 3 > 4
    z = (1+2i) * -1
    print(x)
    return x 
}
'''

# %%
main(code=code, file_dump=False)
# Out:
# --- Parse Tree ---
# (program (const_decl_list (const_decl const (var_decl |ket0> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 1) , (braket_value 0) )))))))) (const_decl const (var_decl |ket1> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 0) , (braket_value 1) )))))))) (const_decl const (var_decl op = (expression (num_expression (num_term (num_factor (dirac_expression (op ( (braket_vector ( (braket_value 1) , (braket_value 0) )) , (braket_vector ( (braket_value 0) , (braket_value 1) )) ))))))))) (const_decl const (var_decl op2 = (expression (num_expression (num_term (num_factor 1) / (num_term (num_factor 2) * (num_term (num_factor (dirac_expression (op ( (braket_vector ( (braket_value 1i) , (braket_value 1i) )) , (braket_vector ( (braket_value 1i) , (braket_value 1i) )) )))))))))))) (main_function main ( ) { (statement_list (statement (assign_statement (var_decl x = (expression (num_expression (num_term (num_factor (dirac_expression (dirac_expression <ket1|) @ (dirac_expression <ket1|))) * (num_term (num_factor (dirac_expression (dirac_expression |ket0>) @ (dirac_expression |ket0>)))))))))) (statement (assign_statement (var_decl y = (expression (bool_expression (bool_or (bool_and (bool_and (bool_cmp (bool_unary (bool_primary ( (bool_expression (bool_or (bool_or (bool_and (bool_cmp (bool_unary (bool_primary ( (bool_expression (bool_or (bool_and (bool_cmp (num_expression (num_term (num_factor 1))) (num_comp <) (num_expression (num_term (num_factor 2))))))) )))))) || (bool_or (bool_and (bool_cmp (bool_unary (bool_primary true))))))) ))))) && (bool_and (bool_cmp (num_expression (num_term (num_factor 3))) (num_comp >) (num_expression (num_term (num_factor 4)))))))))))) (statement (assign_statement (var_decl z = (expression (num_expression (num_term (num_factor ( (num_expression (num_term (num_factor 1)) + (num_expression (num_term (num_factor 2i)))) )) * (num_term (num_factor - (num_factor 1))))))))) (statement (func_call_statement print ( (arg_list (arg x)) ))) (statement (return_statement return (expression x)))) }))
#
# --- Tokens ---
# INDEX  | TEXT       | TYPE            | LINE  | COL
# --------------------------------------------------
# 0      | const      | CONST           | 2     | 0
# 1      | |ket0>     | KET_IDENTIFIER  | 2     | 6
# 2      | =          | ASSIGN          | 2     | 13
# 3      | (          | LPAREN          | 2     | 15
# 4      | 1          | INT             | 2     | 16
# 5      | ,          | COMMA           | 2     | 17
# 6      | 0          | INT             | 2     | 18
# 7      | )          | RPAREN          | 2     | 19
# 8      | const      | CONST           | 3     | 0
# 9      | |ket1>     | KET_IDENTIFIER  | 3     | 6
# 10     | =          | ASSIGN          | 3     | 13
# 11     | (          | LPAREN          | 3     | 15
# 12     | 0          | INT             | 3     | 16
# 13     | ,          | COMMA           | 3     | 17
# 14     | 1          | INT             | 3     | 18
# 15     | )          | RPAREN          | 3     | 19
# 16     | const      | CONST           | 4     | 0
# 17     | op         | IDENTIFIER      | 4     | 6
# 18     | =          | ASSIGN          | 4     | 9
# 19     | (          | LPAREN          | 4     | 11
# 20     | (          | LPAREN          | 4     | 12
# 21     | 1          | INT             | 4     | 13
# 22     | ,          | COMMA           | 4     | 14
# 23     | 0          | INT             | 4     | 15
# 24     | )          | RPAREN          | 4     | 16
# 25     | ,          | COMMA           | 4     | 17
# 26     | (          | LPAREN          | 4     | 19
# 27     | 0          | INT             | 4     | 20
# 28     | ,          | COMMA           | 4     | 21
# 29     | 1          | INT             | 4     | 22
# 30     | )          | RPAREN          | 4     | 23
# 31     | )          | RPAREN          | 4     | 24
# 32     | const      | CONST           | 5     | 0
# 33     | op2        | IDENTIFIER      | 5     | 6
# 34     | =          | ASSIGN          | 5     | 10
# 35     | 1          | INT             | 5     | 12
# 36     | /          | DIV             | 5     | 13
# 37     | 2          | INT             | 5     | 14
# 38     | *          | MUL             | 5     | 16
# 39     | (          | LPAREN          | 5     | 18
# 40     | (          | LPAREN          | 5     | 19
# 41     | 1i         | COMPLEX         | 5     | 20
# 42     | ,          | COMMA           | 5     | 22
# 43     | 1i         | COMPLEX         | 5     | 23
# 44     | )          | RPAREN          | 5     | 25
# 45     | ,          | COMMA           | 5     | 26
# 46     | (          | LPAREN          | 5     | 28
# 47     | 1i         | COMPLEX         | 5     | 29
# 48     | ,          | COMMA           | 5     | 31
# 49     | 1i         | COMPLEX         | 5     | 32
# 50     | )          | RPAREN          | 5     | 34
# 51     | )          | RPAREN          | 5     | 35
# 52     | main       | MAIN            | 7     | 0
# 53     | (          | LPAREN          | 7     | 4
# 54     | )          | RPAREN          | 7     | 5
# 55     | {          | LCURLY          | 7     | 7
# 56     | x          | IDENTIFIER      | 8     | 4
# 57     | =          | ASSIGN          | 8     | 6
# 58     | <ket1|     | BRA_IDENTIFIER  | 8     | 8
# 59     | @          | TENSOR          | 8     | 14
# 60     | <ket1|     | BRA_IDENTIFIER  | 8     | 15
# 61     | *          | MUL             | 8     | 21
# 62     | |ket0>     | KET_IDENTIFIER  | 8     | 22
# 63     | @          | TENSOR          | 8     | 28
# 64     | |ket0>     | KET_IDENTIFIER  | 8     | 29
# 65     | y          | IDENTIFIER      | 9     | 4
# 66     | =          | ASSIGN          | 9     | 6
# 67     | (          | LPAREN          | 9     | 8
# 68     | (          | LPAREN          | 9     | 9
# 69     | 1          | INT             | 9     | 10
# 70     | <          | LT              | 9     | 12
# 71     | 2          | INT             | 9     | 14
# 72     | )          | RPAREN          | 9     | 15
# 73     | ||         | LOGICAL_OR      | 9     | 17
# 74     | true       | BOOL_TRUE       | 9     | 20
# 75     | )          | RPAREN          | 9     | 24
# 76     | &&         | LOGICAL_AND     | 9     | 26
# 77     | 3          | INT             | 9     | 29
# 78     | >          | GT              | 9     | 31
# 79     | 4          | INT             | 9     | 33
# 80     | z          | IDENTIFIER      | 10    | 4
# 81     | =          | ASSIGN          | 10    | 6
# 82     | (          | LPAREN          | 10    | 8
# 83     | 1          | INT             | 10    | 9
# 84     | +          | ADD             | 10    | 10
# 85     | 2i         | COMPLEX         | 10    | 11
# 86     | )          | RPAREN          | 10    | 13
# 87     | *          | MUL             | 10    | 15
# 88     | -          | SUB             | 10    | 17
# 89     | 1          | INT             | 10    | 18
# 90     | print      | IDENTIFIER      | 11    | 4
# 91     | (          | LPAREN          | 11    | 9
# 92     | x          | IDENTIFIER      | 11    | 10
# 93     | )          | RPAREN          | 11    | 11
# 94     | return     | RETURN          | 12    | 4
# 95     | x          | IDENTIFIER      | 12    | 11
# 96     | }          | RCURLY          | 13    | 0
# 97     | <EOF>      | EOF             | 14    | 0
#
# --- Errors ---
# No errors.

# %%
code='''
const |ket0> = (1,0)
const |ket1> = (0,1)
const op = ((1,0), (0,1))
const op2 = 1/2 * ((1i,1i), (1i,1i)) 

main() {
    x = <ket1|@<ket1|*|ket0>@|ket0>
    y = ((1 < 2) || true) && 3 > 4
    z = (1+2i) * -1
    print(x)
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i))
        |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
        |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i))
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i))
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i))
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    |ket0> = (1,0)
    |ket1> = (0,1)
    op = ((1,0), (0,1))
    op2 = 1/2 * ((1i,1i), (1i,1i)) 
    return x 
}
'''

# %%
start_time = time.perf_counter()

main(code=code, file_dump=False)

end_time = time.perf_counter()

elapsed_time = end_time - start_time

print(f"Execution time: {elapsed_time:.6f} seconds")
# Out:
# --- Parse Tree ---
# (program (const_decl_list (const_decl const (var_decl |ket0> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 1) , (braket_value 0) )))))))) (const_decl const (var_decl |ket1> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 0) , (braket_value 1) )))))))) (const_decl const (var_decl op = (expression (num_expression (num_term (num_factor (dirac_expression (op ( (braket_vector ( (braket_value 1) , (braket_value 0) )) , (braket_vector ( (braket_value 0) , (braket_value 1) )) ))))))))) (const_decl const (var_decl op2 = (expression (num_expression (num_term (num_factor 1) / (num_term (num_factor 2) * (num_term (num_factor (dirac_expression (op ( (braket_vector ( (braket_value 1i) , (braket_value 1i) )) , (braket_vector ( (braket_value 1i) , (braket_value 1i) )) )))))))))))) (main_function main ( ) { (statement_list (statement (assign_statement (var_decl x = (expression (num_expression (num_term (num_factor (dirac_expression (dirac_expression <ket1|) @ (dirac_expression <ket1|))) * (num_term (num_factor (dirac_expression (dirac_expression |ket0>) @ (dirac_expression |ket0>)))))))))) (statement (assign_statement (var_decl y = (expression (bool_expression (bool_or (bool_and (bool_and (bool_cmp (bool_unary (bool_primary ( (bool_expression (bool_or (bool_or (bool_and (bool_cmp (bool_unary (bool_primary ( (bool_expression (bool_or (bool_and (bool_cmp (num_expression (num_term (num_factor 1))) (num_comp <) (num_expression (num_term (num_factor 2))))))) )))))) || (bool_or (bool_and (bool_cmp (bool_unary (bool_primary true))))))) ))))) && (bool_and (bool_cmp (num_expression (num_term (num_factor 3))) (num_comp >) (num_expression (num_term (num_factor 4)))))))))))) (statement (assign_statement (var_decl z = (expression (num_expression (num_term (num_factor ( (num_expression (num_term (num_factor 1)) + (num_expression (num_term (num_factor 2i)))) )) * (num_term (num_factor - (num_factor 1))))))))) (statement (func_call_statement print ( (arg_list (arg x)) ))) (statement (assign_statement (var_decl |ket0> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 1) , (braket_value 0) ))))))))) (statement (assign_statement (var_decl |ket1> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 0) , (braket_value 1) ))))))))) (statement (assign_statement (var_decl op = (expression (num_expression (num_term (num_factor (dirac_expression (op ( (braket_vector ( (braket_value 1) , (braket_value 0) )) , (braket_vector ( (braket_value 0) , (braket_value 1) )) )))))))))) (statement (assign_statement (var_decl op2 = (expression (num_expression (num_term (num_factor 1) / (num_term (num_factor 2) * (num_term (num_factor (dirac_expression (op ( (braket_vector ( (braket_value 1i) , (braket_value 1i) )) , (braket_vector ( (braket_value 1i) , (braket_value 1i) )) )))))))))))) (statement (assign_statement (var_decl |ket0> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 1) , (braket_value 0) ))))))))) (statement (assign_statement (var_decl |ket1> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 0) , (braket_value 1) ))))))))) (statement (assign_statement (var_decl op = (expression (num_expression (num_term (num_factor (dirac_expression (op ( (braket_vector ( (braket_value 1) , (braket_value 0) )) , (braket_vector ( (braket_value 0) , (braket_value 1) )) )))))))))) (statement (assign_statement (var_decl op2 = (expression (num_expression (num_term (num_factor 1) / (num_term (num_factor 2) * (num_term (num_factor (dirac_expression (op ( (braket_vector ( (braket_value 1i) , (braket_value 1i) )) , (braket_vector ( (braket_value 1i) , (braket_value 1i) )) )))))))))))) (statement (assign_statement (var_decl |ket0> = (num_expression (num_term (num_factor (dirac_expression (braket_vector ( (braket_value 1) , (braket_value 0) ))))))))) (statement (a ...
#
# --- Tokens ---
# INDEX  | TEXT       | TYPE            | LINE  | COL
# --------------------------------------------------
# 0      | const      | CONST           | 2     | 0
# 1      | |ket0>     | KET_IDENTIFIER  | 2     | 6
# 2      | =          | ASSIGN          | 2     | 13
# 3      | (          | LPAREN          | 2     | 15
# 4      | 1          | INT             | 2     | 16
# 5      | ,          | COMMA           | 2     | 17
# 6      | 0          | INT             | 2     | 18
# 7      | )          | RPAREN          | 2     | 19
# 8      | const      | CONST           | 3     | 0
# 9      | |ket1>     | KET_IDENTIFIER  | 3     | 6
# 10     | =          | ASSIGN          | 3     | 13
# 11     | (          | LPAREN          | 3     | 15
# 12     | 0          | INT             | 3     | 16
# 13     | ,          | COMMA           | 3     | 17
# 14     | 1          | INT             | 3     | 18
# 15     | )          | RPAREN          | 3     | 19
# 16     | const      | CONST           | 4     | 0
# 17     | op         | IDENTIFIER      | 4     | 6
# 18     | =          | ASSIGN          | 4     | 9
# 19     | (          | LPAREN          | 4     | 11
# 20     | (          | LPAREN          | 4     | 12
# 21     | 1          | INT             | 4     | 13
# 22     | ,          | COMMA           | 4     | 14
# 23     | 0          | INT             | 4     | 15
# 24     | )          | RPAREN          | 4     | 16
# 25     | ,          | COMMA           | 4     | 17
# 26     | (          | LPAREN          | 4     | 19
# 27     | 0          | INT             | 4     | 20
# 28     | ,          | COMMA           | 4     | 21
# 29     | 1          | INT             | 4     | 22
# 30     | )          | RPAREN          | 4     | 23
# 31     | )          | RPAREN          | 4     | 24
# 32     | const      | CONST           | 5     | 0
# 33     | op2        | IDENTIFIER      | 5     | 6
# 34     | =          | ASSIGN          | 5     | 10
# 35     | 1          | INT             | 5     | 12
# 36     | /          | DIV             | 5     | 13
# 37     | 2          | INT             | 5     | 14
# 38     | *          | MUL             | 5     | 16
# 39     | (          | LPAREN          | 5     | 18
# 40     | (          | LPAREN          | 5     | 19
# 41     | 1i         | COMPLEX         | 5     | 20
# 42     | ,          | COMMA           | 5     | 22
# 43     | 1i         | COMPLEX         | 5     | 23
# 44     | )          | RPAREN          | 5     | 25
# 45     | ,          | COMMA           | 5     | 26
# 46     | (          | LPAREN          | 5     | 28
# 47     | 1i         | COMPLEX         | 5     | 29
# 48     | ,          | COMMA           | 5     | 31
# 49     | 1i         | COMPLEX         | 5     | 32
# 50     | )          | RPAREN          | 5     | 34
# 51     | )          | RPAREN          | 5     | 35
# 52     | main       | MAIN            | 7     | 0
# 53     | (          | LPAREN          | 7     | 4
# 54     | )          | RPAREN          | 7     | 5
# 55     | {          | LCURLY          | 7     | 7
# 56     | x          | IDENTIFIER      | 8     | 4
# 57     | =          | ASSIGN          | 8     | 6
# 58     | <ket1|     | BRA_IDENTIFIER  | 8     | 8
# 59     | @          | TENSOR          | 8     | 14
# 60     | <ket1|     | BRA_IDENTIFIER  | 8     | 15
# 61     | *          | MUL             | 8     | 21
# 62     | |ket0>     | KET_IDENTIFIER  | 8     | 22
# 63     | @          | TENSOR          | 8     | 28
# 64     | |ket0>     | KET_IDENTIFIER  | 8     | 29
# 65     | y          | IDENTIFIER      | 9     | 4
# 66     | =          | ASSIGN          | 9     | 6
# 67     | (          | LPAREN          | 9     | 8
# 68     | (          | LPAREN          | 9     | 9
# 69     | 1          | INT             | 9     | 10
# 70     | <          | LT              | 9     | 12
# 71     | 2          | INT             | 9     | 14
# 72     | )          | RPAREN          | 9     | 15
# 73     | ||         | LOGICAL_OR      | 9     | 17
# 74     | true       | BOOL_TRUE       | 9     | 20
# 75     | )          | RPAREN          | 9     | 24
# 76     | &&         | LOGICAL_AND     | 9     | 26
# 77     | 3          | INT             | 9     | 29
# 78     | >          | GT              | 9     | 31
# 79     | 4          | INT             | 9     | 33
# 80     | z          | IDENTIFIER      | 10    | 4
# 81     | =          | ASSIGN          | 10    | 6
# 82     | (          | LPAREN          | 10    | 8
# 83     | 1          | INT             | 10    | 9
# 84     | +          | ADD             | 10    | 10
# 85     | 2i         | COMPLEX         | 10    | 11
# 86     | )          | RPAREN          | 10    | 13
# 87     | *          | MUL             | 10    | 15
# 88     | -          | SUB             | 10    | 17
# 89     | 1          | INT             | 10    | 18
# 90     | print      | IDENTIFIER      | 11    | 4
# 91     | (          | LPAREN          | 11    | 9
# 92     | x          | IDENTIFIER      | 11    | 10
# 93     | )          | RPAREN          | 11    | 11
# 94     | |ket0>     | KET_IDENTIFIER  | 12    | 4
# 95     | =          | ASSIGN          | 12    | 11
# 96     | (          | LPAREN          | 12    | 13
# 97     | 1          | INT             | 12    | 14
# 98     | ,          | COMMA           | 12    | 15
# 99     | 0          | INT             | 12    | 16
# 100    | )          | RPAREN          | 12    | 17
# 101    | |ket1>     | KET_IDENTIFIER  | 13    | 4
# 102    | =          | ASSIGN          | 13    | 11
# 103    | (          | LPAREN          | 13    | 13
# 104    | 0          | INT             | 13    | 14
# 105    | ,          | COMMA           | 13    | 15
# 106    | 1          | INT             | 13    | 16
# 107    | )          | RPAREN          | 13    | 17
# 108    | op         | IDENTIFIER      | 14    | 4
# 109    | =          | ASSIGN          | 14    | 7
# 110    | (          | LPAREN          | 14    | 9
# 111    | (          | LPAREN          | 14    | 10
# 112    | 1          | INT             | 14    | 11
# 113    | ,          | COMMA           | 14    | 12
# 114    | 0          | INT             | 14    | 13
# 115    | )          | RPAREN          | 14    | 14
# 116    | ,          | COMMA           | 14    | 15
# 117    | (          | LPAREN          | 14    | 17
# 118    | 0          | INT             | 14    | 18
# 119    | ,          | COMMA           | 14    | 19
# 120    | 1          | INT             | 14    | 20
# 121    | )          | RPAREN          | 14    | 21
# 122    | )          | RPAREN          | 14    | 22
# 123    | op2        | IDENTIFIER      | 15    | 4
# 124    | =          | ASSIGN          | 15    | 8
# 125    | 1          | INT             | 15    | 10
# 126    | /          | DIV             | 15    | 11
# 127    | 2          | INT             | 15    | 12
# 128    | *          | MUL             | 15    | 14
# 129    | (          | LPAREN          | 15    | 16
# 130    | (          | LPAREN          | 15    | 17
# 131    | 1i         | COMPLEX         | 15    | 18
# 132    | ,          | COMMA           | 15    | 20
# 133    | 1i         | COMPLEX         | 15    | 21
# 134    | )          | RPAREN          | 15    | 23
# 135    | ,          | COMMA           | 15    | 24
# 136    | (          | LPAREN          | 15    | 26
# 137    | 1i         | COMPLEX         | 15    | 27
# 138    | ,          | COMMA           | 15    | 29
# 139    | 1i         | COMPLEX         | 15    | 30
# 140    | )          | RPAREN          | 15    | 32
# 141    | )          | RPAREN          | 15    | 33
# 142    | |ket0>     | KET_IDENTIFIER  | 16    | 4
# 143    | =          | ASSIGN          | 16    | 11
# 144    | (          | LPAREN          | 16    | 13
# 145    | 1          | INT             | 16    | 14
# 146    | ,          | COMMA           | 16    | 15
# 147    | 0          | INT             | 16    | 16
# 148    | )          | RPAREN          | 16    | 17
# 149    | |ket1>     | KET_IDENTIFIER  | 17    | 4
# 150    | =          | ASSIGN          | 17    | 11
# 151    | (          | LPAREN          | 17    | 13
# 152    | 0          | INT             | 17    | 14
# 153    | ,          | COMMA           | 17    | 15
# 154    | 1          | INT             | 17    | 16
# 155    | )          | RPAREN          | 17    | 17
# 156    | op         | IDENTIFIER      | 18    | 4
# 157    | =          | ASSIGN          | 18    | 7
# 158    | (          | LPAREN          | 18    | 9
# 159    | (          | LPAREN          | 18    | 10
# 160    | 1          | INT             | 18    | 11
# 161    | ,          | COMMA           | 18    | 12
# 162    | 0          | INT             | 18    | 13
# 163    | )          | RPAREN          | 18    | 14
# 164    | ,          | COMMA           | 18    | 15
# 165    | (          | LPAREN          | 18    | 17
# 166    | 0          | INT             | 18    | 18
# 167    | ,          | COMMA           | 18    | 19
# 168    | 1          | INT             | 18    | 20
# 169    | )          | RPAREN          | 18    | 21
# 170    | )          | RPAREN          | 18    | 22
# 171    | op2        | IDENTIFIER      | 19    | 4
# 172    | =          | ASSIGN          | 19    | 8
# 173    | 1          | INT             | 19    | 10
# 174    | /          | DIV             | 19    | 11
# 175    | 2          | INT             | 19    | 12
# 176    | *          | MUL             | 19    | 14
# 177    | (          | LPAREN          | 19    | 16
# 178    | (          | LPAREN          | 19    | 17
# 179    | 1i         | COMPLEX         | 19    | 18
# 180    | ,          | COMMA           | 19    | 20
# 181    | 1i         | COMPLEX         | 19    | 21
# 182    | )          | RPAREN          | 19    | 23
# 183    | ,          | COMMA           | 19    | 24
# 184    | (          | LPAREN          | 19    | 26
# 185    | 1i         | COMPLEX         | 19    | 27
# 186    | ,          | COMMA           | 19    | 29
# 187    | 1i         | COMPLEX         | 19    | 30
# 188    | )          | RPAREN          | 19    | 32
# 189    | )          | RPAREN          | 19    | 33
# 190    | |ket0>     | KET_IDENTIFIER  | 20    | 8
# 191    | =          | ASSIGN          | 20    | 15
# 192    | (          | LPAREN          | 20    | 17
# 193    | 1          | INT             | 20    | 18
# 194    | ,          | COMMA           | 20    | 19
# 195    | 0          | INT             | 20    | 20
# 196    | )          | RPAREN          | 20    | 21
# 197    | |ket1>     | KET_IDENTIFIER  | 21    | 4
# 198    | =          | ASSIGN          | 21    | 11
# 199    | (          | LPAREN          | 21    | 13
# 200    | 0          | INT             | 21    | 14
# 201    | ,          | COMMA           | 21    | 15
# 202    | 1          | INT             | 21    | 16
# 203    | )          | RPAREN          | 21    | 17
# 204    | op         | IDENTIFIER      | 22    | 4
# 205    | =          | ASSIGN          | 22    | 7
# 206    | (          | LPAREN          | 22    | 9
# 207    | (          | LPAREN          | 22    | 10
# 208    | 1          | INT             | 22    | 11
# 209    | ,          | COMMA           | 22    | 12
# 210    | 0          | INT             | 22    | 13
# 211    | )          | RPAREN          | 22    | 14
# 212    | ,          | COMMA           | 22    | 15
# 213    | (          | LPAREN          | 22    | 17
# 214    | 0          | INT             | 22    | 18
# 215    | ,          | COMMA           | 22    | 19
# 216    | 1          | INT             | 22    | 20
# 217    | )          | RPAREN          | 22    | 21
# 218    | )          | RPAREN          | 22    | 22
# 219    | op2        | IDENTIFIER      | 23    | 4
# 220    | =          | ASSIGN          | 23    | 8
# 221    | 1          | INT             | 23    | 10
# 222    | /          | DIV             | 23    | 11
# 223    | 2          | INT             | 23    | 12
# 224    | *          | MUL             | 23    | 14
# 225    | (          | LPAREN          | 23    | 16
# 226    | (          | LPAREN          | 23    | 17
# 227    | 1i         | COMPLEX         | 23    | 18
# 228    | ,          | COMMA           | 23    | 20
# 229    | 1i         | COMPLEX         | 23    | 21
# 230    | )          | RPAREN          | 23    | 23
# 231    | ,          | COMMA           | 23    | 24
# 232    | (          | LPAREN          | 23    | 26
# 233    | 1i         | COMPLEX         | 23    | 27
# 234    | ,          | COMMA           | 23    | 29
# 235    | 1i         | COMPLEX         | 23    | 30
# 236    | )          | RPAREN          | 23    | 32
# 237    | )          | RPAREN          | 23    | 33
# 238    | |ket0>     | KET_IDENTIFIER  | 24    | 4
# 239    | =          | ASSIGN          | 24    | 11
# 240    | (          | LPAREN          | 24    | 13
# 241    | 1          | INT             | 24    | 14
# 242    | ,          | COMMA           | 24    | 15
# 243    | 0          | INT             | 24    | 16
# 244    | )          | RPAREN          | 24    | 17
# 245    | |ket1>     | KET_IDENTIFIER  | 25    | 4
# 246    | =          | ASSIGN          | 25    | 11
# 247    | (          | LPAREN          | 25    | 13
# 248    | 0          | INT             | 25    | 14
# 249    | ,          | COMMA           | 25    | 15
# 250    | 1          | INT             | 25    | 16
# 251    | )          | RPAREN          | 25    | 17
# 252    | op         | IDENTIFIER      | 26    | 4
# 253    | =          | ASSIGN          | 26    | 7
# 254    | (          | LPAREN          | 26    | 9
# 255    | (          | LPAREN          | 26    | 10
# 256    | 1          | INT             | 26    | 11
# 257    | ,          | COMMA           | 26    | 12
# 258    | 0          | INT             | 26    | 13
# 259    | )          | RPAREN          | 26    | 14
# 260    | ,          | COMMA           | 26    | 15
# 261    | (          | LPAREN          | 26    | 17
# 262    | 0          | INT             | 26    | 18
# 263    | ,          | COMMA           | 26    | 19
# 264    | 1          | INT             | 26    | 20
# 265    | )          | RPAREN          | 26    | 21
# 266    | )          | RPAREN          | 26    | 22
# 267    | op2        | IDENTIFIER      | 27    | 4
# 268    | =          | ASSIGN          | 27    | 8
# 269    | 1          | INT             | 27    | 10
# 270    | /          | DIV             | 27    | 11
# 271    | 2          | INT             | 27    | 12
# 272    | *          | MUL             | 27    | 14
# 273    | (          | LPAREN          | 27    | 16
# 274    | (          | LPAREN          | 27    | 17
# 275    | 1i         | COMPLEX         | 27    | 18
# 276    | ,          | COMMA           | 27    | 20
# 277    | 1i         | COMPLEX         | 27    | 21
# 278    | )          | RPAREN          | 27    | 23
# 279    | ,          | COMMA           | 27    | 24
# 280    | (          | LPAREN          | 27    | 26
# 281    | 1i         | COMPLEX         | 27    | 27
# 282    | ,          | COMMA           | 27    | 29
# 283    | 1i         | COMPLEX         | 27    | 30
# 284    | )          | RPAREN          | 27    | 32
# 285    | )          | RPAREN          | 27    | 33
# 286    | |ket0>     | KET_IDENTIFIER  | 28    | 8
# 287    | =          | ASSIGN          | 28    | 15
# 288    | (          | LPAREN          | 28    | 17
# 289    | 1          | INT             | 28    | 18
# 290    | ,          | COMMA           | 28    | 19
# 291    | 0          | INT             | 28    | 20
# 292    | )          | RPAREN          | 28    | 21
# 293    | |ket1>     | KET_IDENTIFIER  | 29    | 4
# 294    | =          | ASSIGN          | 29    | 11
# 295    | (          | LPAREN          | 29    | 13
# 296    | 0          | INT             | 29    | 14
# 297    | ,          | COMMA           | 29    | 15
# 298    | 1          | INT             | 29    | 16
# 299    | )          | RPAREN          | 29    | 17
# 300    | op         | IDENTIFIER      | 30    | 4
# 301    | =          | ASSIGN          | 30    | 7
# 302    | (          | LPAREN          | 30    | 9
# 303    | (          | LPAREN          | 30    | 10
# 304    | 1          | INT             | 30    | 11
# 305    | ,          | COMMA           | 30    | 12
# 306    | 0          | INT             | 30    | 13
# 307    | )          | RPAREN          | 30    | 14
# 308    | ,          | COMMA           | 30    | 15
# 309    | (          | LPAREN          | 30    | 17
# 310    | 0          | INT             | 30    | 18
# 311    | ,          | COMMA           | 30    | 19
# 312    | 1          | INT             | 30    | 20
# 313    | )          | RPAREN          | 30    | 21
# 314    | )          | RPAREN          | 30    | 22
# 315    | op2        | IDENTIFIER      | 31    | 4
# 316    | =          | ASSIGN          | 31    | 8
# 317    | 1          | INT             | 31    | 10
# 318    | /          | DIV             | 31    | 11
# 319    | 2          | INT             | 31    | 12
# 320    | *          | MUL             | 31    | 14
# 321    | (          | LPAREN          | 31    | 16
# 322    | (          | LPAREN          | 31    | 17
# 323    | 1i         | COMPLEX         | 31    | 18
# 324    | ,          | COMMA           | 31    | 20
# 325    | 1i         | COMPLEX         | 31    | 21
# 326    | )          | RPAREN          | 31    | 23
# 327    | ,          | COMMA           | 31    | 24
# 328    | (          | LPAREN          | 31    | 26
# 329    | 1i         | COMPLEX         | 31    | 27
# 330    | ,          | COMMA           | 31    | 29
# 331    | 1i         | COMPLEX         | 31    | 30
# 332    | )          | RPAREN          | 31    | 32
# 333    | )          | RPAREN          | 31    | 33
# 334    | |ket0>     | KET_IDENTIFIER  | 32    | 4
# 335    | =          | ASSIGN          | 32    | 11
# 336    | (          | LPAREN          | 32    | 13
# 337    | 1          | INT             | 32    | 14
# 338    | ,          | COMMA           | 32    | 15
# 339    | 0          | INT             | 32    | 16
# 340    | )          | RPAREN          | 32    | 17
# 341    | |ket1>     | KET_IDENTIFIER  | 33    | 4
# 342    | =          | ASSIGN          | 33    | 11
# 343    | (          | LPAREN          | 33    | 13
# 344    | 0          | INT             | 33    | 14
# 345    | ,          | COMMA           | 33    | 15
# 346    | 1          | INT             | 33    | 16
# 347    | )          | RPAREN          | 33    | 17
# 348    | op         | IDENTIFIER      | 34    | 4
# 349    | =          | ASSIGN          | 34    | 7
# 350    | (          | LPAREN          | 34    | 9
# 351    | (          | LPAREN          | 34    | 10
# 352    | 1          | INT             | 34    | 11
# 353    | ,          | COMMA           | 34    | 12
# 354    | 0          | INT             | 34    | 13
# 355    | )          | RPAREN          | 34    | 14
# 356    | ,          | COMMA           | 34    | 15
# 357    | (          | LPAREN          | 34    | 17
# 358    | 0          | INT             | 34    | 18
# 359    | ,          | COMMA           | 34    | 19
# 360    | 1          | INT             | 34    | 20
# 361    | )          | RPAREN          | 34    | 21
# 362    | )          | RPAREN          | 34    | 22
# 363    | op2        | IDENTIFIER      | 35    | 4
# 364    | =          | ASSIGN          | 35    | 8
# 365    | 1          | INT             | 35    | 10
# 366    | /          | DIV             | 35    | 11
# 367    | 2          | INT             | 35    | 12
# 368    | *          | MUL             | 35    | 14
# 369    | (          | LPAREN          | 35    | 16
# 370    | (          | LPAREN          | 35    | 17
# 371    | 1i         | COMPLEX         | 35    | 18
# 372    | ,          | COMMA           | 35    | 20
# 373    | 1i         | COMPLEX         | 35    | 21
# 374    | )          | RPAREN          | 35    | 23
# 375    | ,          | COMMA           | 35    | 24
# 376    | (          | LPAREN          | 35    | 26
# 377    | 1i         | COMPLEX         | 35    | 27
# 378    | ,          | COMMA           | 35    | 29
# 379    | 1i         | COMPLEX         | 35    | 30
# 380    | )          | RPAREN          | 35    | 32
# 381    | )          | RPAREN          | 35    | 33
# 382    | |ket0>     | KET_IDENTIFIER  | 36    | 4
# 383    | =          | ASSIGN          | 36    | 11
# 384    | (          | LPAREN          | 36    | 13
# 385    | 1          | INT             | 36    | 14
# 386    | ,          | COMMA           | 36    | 15
# 387    | 0          | INT             | 36    | 16
# 388    | )          | RPAREN          | 36    | 17
# 389    | |ket1>     | KET_IDENTIFIER  | 37    | 4
# 390    | =          | ASSIGN          | 37    | 11
# 391    | (          | LPAREN          | 37    | 13
# 392    | 0          | INT             | 37    | 14
# 393    | ,          | COMMA           | 37    | 15
# 394    | 1          | INT             | 37    | 16
# 395    | )          | RPAREN          | 37    | 17
# 396    | op         | IDENTIFIER      | 38    | 4
# 397    | =          | ASSIGN          | 38    | 7
# 398    | (          | LPAREN          | 38    | 9
# 399    | (          | LPAREN          | 38    | 10
# 400    | 1          | INT             | 38    | 11
# 401    | ,          | COMMA           | 38    | 12
# 402    | 0          | INT             | 38    | 13
# 403    | )          | RPAREN          | 38    | 14
# 404    | ,          | COMMA           | 38    | 15
# 405    | (          | LPAREN          | 38    | 17
# 406    | 0          | INT             | 38    | 18
# 407    | ,          | COMMA           | 38    | 19
# 408    | 1          | INT             | 38    | 20
# 409    | )          | RPAREN          | 38    | 21
# 410    | )          | RPAREN          | 38    | 22
# 411    | op2        | IDENTIFIER      | 39    | 4
# 412    | =          | ASSIGN          | 39    | 8
# 413    | 1          | INT             | 39    | 10
# 414    | /          | DIV             | 39    | 11
# 415    | 2          | INT             | 39    | 12
# 416    | *          | MUL             | 39    | 14
# 417    | (          | LPAREN          | 39    | 16
# 418    | (          | LPAREN          | 39    | 17
# 419    | 1i         | COMPLEX         | 39    | 18
# 420    | ,          | COMMA           | 39    | 20
# 421    | 1i         | COMPLEX         | 39    | 21
# 422    | )          | RPAREN          | 39    | 23
# 423    | ,          | COMMA           | 39    | 24
# 424    | (          | LPAREN          | 39    | 26
# 425    | 1i         | COMPLEX         | 39    | 27
# 426    | ,          | COMMA           | 39    | 29
# 427    | 1i         | COMPLEX         | 39    | 30
# 428    | )          | RPAREN          | 39    | 32
# 429    | )          | RPAREN          | 39    | 33
# 430    | |ket0>     | KET_IDENTIFIER  | 40    | 4
# 431    | =          | ASSIGN          | 40    | 11
# 432    | (          | LPAREN          | 40    | 13
# 433    | 1          | INT             | 40    | 14
# 434    | ,          | COMMA           | 40    | 15
# 435    | 0          | INT             | 40    | 16
# 436    | )          | RPAREN          | 40    | 17
# 437    | |ket1>     | KET_IDENTIFIER  | 41    | 4
# 438    | =          | ASSIGN          | 41    | 11
# 439    | (          | LPAREN          | 41    | 13
# 440    | 0          | INT             | 41    | 14
# 441    | ,          | COMMA           | 41    | 15
# 442    | 1          | INT             | 41    | 16
# 443    | )          | RPAREN          | 41    | 17
# 444    | op         | IDENTIFIER      | 42    | 4
# 445    | =          | ASSIGN          | 42    | 7
# 446    | (          | LPAREN          | 42    | 9
# 447    | (          | LPAREN          | 42    | 10
# 448    | 1          | INT             | 42    | 11
# 449    | ,          | COMMA           | 42    | 12
# 450    | 0          | INT             | 42    | 13
# 451    | )          | RPAREN          | 42    | 14
# 452    | ,          | COMMA           | 42    | 15
# 453    | (          | LPAREN          | 42    | 17
# 454    | 0          | INT             | 42    | 18
# 455    | ,          | COMMA           | 42    | 19
# 456    | 1          | INT             | 42    | 20
# 457    | )          | RPAREN          | 42    | 21
# 458    | )          | RPAREN          | 42    | 22
# 459    | op2        | IDENTIFIER      | 43    | 4
# 460    | =          | ASSIGN          | 43    | 8
# 461    | 1          | INT             | 43    | 10
# 462    | /          | DIV             | 43    | 11
# 463    | 2          | INT             | 43    | 12
# 464    | *          | MUL             | 43    | 14
# 465    | (          | LPAREN          | 43    | 16
# 466    | (          | LPAREN          | 43    | 17
# 467    | 1i         | COMPLEX         | 43    | 18
# 468    | ,          | COMMA           | 43    | 20
# 469    | 1i         | COMPLEX         | 43    | 21
# 470    | )          | RPAREN          | 43    | 23
# 471    | ,          | COMMA           | 43    | 24
# 472    | (          | LPAREN          | 43    | 26
# 473    | 1i         | COMPLEX         | 43    | 27
# 474    | ,          | COMMA           | 43    | 29
# 475    | 1i         | COMPLEX         | 43    | 30
# 476    | )          | RPAREN          | 43    | 32
# 477    | )          | RPAREN          | 43    | 33
# 478    | |ket0>     | KET_IDENTIFIER  | 44    | 4
# 479    | =          | ASSIGN          | 44    | 11
# 480    | (          | LPAREN          | 44    | 13
# 481    | 1          | INT             | 44    | 14
# 482    | ,          | COMMA           | 44    | 15
# 483    | 0          | INT             | 44    | 16
# 484    | )          | RPAREN          | 44    | 17
# 485    | |ket1>     | KET_IDENTIFIER  | 45    | 4
# 486    | =          | ASSIGN          | 45    | 11
# 487    | (          | LPAREN          | 45    | 13
# 488    | 0          | INT             | 45    | 14
# 489    | ,          | COMMA           | 45    | 15
# 490    | 1          | INT             | 45    | 16
# 491    | )          | RPAREN          | 45    | 17
# 492    | op         | IDENTIFIER      | 46    | 4
# 493    | =          | ASSIGN          | 46    | 7
# 494    | (          | LPAREN          | 46    | 9
# 495    | (          | LPAREN          | 46    | 10
# 496    | 1          | INT             | 46    | 11
# 497    | ,          | COMMA           | 46    | 12
# 498    | 0          | INT             | 46    | 13
# 499    | )          | RPAREN          | 46    | 14
# 500    | ,          | COMMA           | 46    | 15
# 501    | (          | LPAREN          | 46    | 17
# 502    | 0          | INT             | 46    | 18
# 503    | ,          | COMMA           | 46    | 19
# 504    | 1          | INT             | 46    | 20
# 505    | )          | RPAREN          | 46    | 21
# 506    | )          | RPAREN          | 46    | 22
# 507    | op2        | IDENTIFIER      | 47    | 4
# 508    | =          | ASSIGN          | 47    | 8
# 509    | 1          | INT             | 47    | 10
# 510    | /          | DIV             | 47    | 11
# 511    | 2          | INT             | 47    | 12
# 512    | *          | MUL             | 47    | 14
# 513    | (          | LPAREN          | 47    | 16
# 514    | (          | LPAREN          | 47    | 17
# 515    | 1i         | COMPLEX         | 47    | 18
# 516    | ,          | COMMA           | 47    | 20
# 517    | 1i         | COMPLEX         | 47    | 21
# 518    | )          | RPAREN          | 47    | 23
# 519    | ,          | COMMA           | 47    | 24
# 520    | (          | LPAREN          | 47    | 26
# 521    | 1i         | COMPLEX         | 47    | 27
# 522    | ,          | COMMA           | 47    | 29
# 523    | 1i         | COMPLEX         | 47    | 30
# 524    | )          | RPAREN          | 47    | 32
# 525    | )          | RPAREN          | 47    | 33
# 526    | |ket0>     | KET_IDENTIFIER  | 48    | 4
# 527    | =          | ASSIGN          | 48    | 11
# 528    | (          | LPAREN          | 48    | 13
# 529    | 1          | INT             | 48    | 14
# 530    | ,          | COMMA           | 48    | 15
# 531    | 0          | INT             | 48    | 16
# 532    | )          | RPAREN          | 48    | 17
# 533    | |ket1>     | KET_IDENTIFIER  | 49    | 4
# 534    | =          | ASSIGN          | 49    | 11
# 535    | (          | LPAREN          | 49    | 13
# 536    | 0          | INT             | 49    | 14
# 537    | ,          | COMMA           | 49    | 15
# 538    | 1          | INT             | 49    | 16
# 539    | )          | RPAREN          | 49    | 17
# 540    | op         | IDENTIFIER      | 50    | 4
# 541    | =          | ASSIGN          | 50    | 7
# 542    | (          | LPAREN          | 50    | 9
# 543    | (          | LPAREN          | 50    | 10
# 544    | 1          | INT             | 50    | 11
# 545    | ,          | COMMA           | 50    | 12
# 546    | 0          | INT             | 50    | 13
# 547    | )          | RPAREN          | 50    | 14
# 548    | ,          | COMMA           | 50    | 15
# 549    | (          | LPAREN          | 50    | 17
# 550    | 0          | INT             | 50    | 18
# 551    | ,          | COMMA           | 50    | 19
# 552    | 1          | INT             | 50    | 20
# 553    | )          | RPAREN          | 50    | 21
# 554    | )          | RPAREN          | 50    | 22
# 555    | op2        | IDENTIFIER      | 51    | 4
# 556    | =          | ASSIGN          | 51    | 8
# 557    | 1          | INT             | 51    | 10
# 558    | /          | DIV             | 51    | 11
# 559    | 2          | INT             | 51    | 12
# 560    | *          | MUL             | 51    | 14
# 561    | (          | LPAREN          | 51    | 16
# 562    | (          | LPAREN          | 51    | 17
# 563    | 1i         | COMPLEX         | 51    | 18
# 564    | ,          | COMMA           | 51    | 20
# 565    | 1i         | COMPLEX         | 51    | 21
# 566    | )          | RPAREN          | 51    | 23
# 567    | ,          | COMMA           | 51    | 24
# 568    | (          | LPAREN          | 51    | 26
# 569    | 1i         | COMPLEX         | 51    | 27
# 570    | ,          | COMMA           | 51    | 29
# 571    | 1i         | COMPLEX         | 51    | 30
# 572    | )          | RPAREN          | 51    | 32
# 573    | )          | RPAREN          | 51    | 33
# 574    | |ket0>     | KET_IDENTIFIER  | 52    | 4
# 575    | =          | ASSIGN          | 52    | 11
# 576    | (          | LPAREN          | 52    | 13
# 577    | 1          | INT             | 52    | 14
# 578    | ,          | COMMA           | 52    | 15
# 579    | 0          | INT             | 52    | 16
# 580    | )          | RPAREN          | 52    | 17
# 581    | |ket1>     | KET_IDENTIFIER  | 53    | 4
# 582    | =          | ASSIGN          | 53    | 11
# 583    | (          | LPAREN          | 53    | 13
# 584    | 0          | INT             | 53    | 14
# 585    | ,          | COMMA           | 53    | 15
# 586    | 1          | INT             | 53    | 16
# 587    | )          | RPAREN          | 53    | 17
# 588    | op         | IDENTIFIER      | 54    | 4
# 589    | =          | ASSIGN          | 54    | 7
# 590    | (          | LPAREN          | 54    | 9
# 591    | (          | LPAREN          | 54    | 10
# 592    | 1          | INT             | 54    | 11
# 593    | ,          | COMMA           | 54    | 12
# 594    | 0          | INT             | 54    | 13
# 595    | )          | RPAREN          | 54    | 14
# 596    | ,          | COMMA           | 54    | 15
# 597    | (          | LPAREN          | 54    | 17
# 598    | 0          | INT             | 54    | 18
# 599    | ,          | COMMA           | 54    | 19
# 600    | 1          | INT             | 54    | 20
# 601    | )          | RPAREN          | 54    | 21
# 602    | )          | RPAREN          | 54    | 22
# 603    | op2        | IDENTIFIER      | 55    | 4
# 604    | =          | ASSIGN          | 55    | 8
# 605    | 1          | INT             | 55    | 10
# 606    | /          | DIV             | 55    | 11
# 607    | 2          | INT             | 55    | 12
# 608    | *          | MUL             | 55    | 14
# 609    | (          | LPAREN          | 55    | 16
# 610    | (          | LPAREN          | 55    | 17
# 611    | 1i         | COMPLEX         | 55    | 18
# 612    | ,          | COMMA           | 55    | 20
# 613    | 1i         | COMPLEX         | 55    | 21
# 614    | )          | RPAREN          | 55    | 23
# 615    | ,          | COMMA           | 55    | 24
# 616    | (          | LPAREN          | 55    | 26
# 617    | 1i         | COMPLEX         | 55    | 27
# 618    | ,          | COMMA           | 55    | 29
# 619    | 1i         | COMPLEX         | 55    | 30
# 620    | )          | RPAREN          | 55    | 32
# 621    | )          | RPAREN          | 55    | 33
# 622    | |ket0>     | KET_IDENTIFIER  | 56    | 4
# 623    | =          | ASSIGN          | 56    | 11
# 624    | (          | LPAREN          | 56    | 13
# 625    | 1          | INT             | 56    | 14
# 626    | ,          | COMMA           | 56    | 15
# 627    | 0          | INT             | 56    | 16
# 628    | )          | RPAREN          | 56    | 17
# 629    | |ket1>     | KET_IDENTIFIER  | 57    | 4
# 630    | =          | ASSIGN          | 57    | 11
# 631    | (          | LPAREN          | 57    | 13
# 632    | 0          | INT             | 57    | 14
# 633    | ,          | COMMA           | 57    | 15
# 634    | 1          | INT             | 57    | 16
# 635    | )          | RPAREN          | 57    | 17
# 636    | op         | IDENTIFIER      | 58    | 4
# 637    | =          | ASSIGN          | 58    | 7
# 638    | (          | LPAREN          | 58    | 9
# 639    | (          | LPAREN          | 58    | 10
# 640    | 1          | INT             | 58    | 11
# 641    | ,          | COMMA           | 58    | 12
# 642    | 0          | INT             | 58    | 13
# 643    | )          | RPAREN          | 58    | 14
# 644    | ,          | COMMA           | 58    | 15
# 645    | (          | LPAREN          | 58    | 17
# 646    | 0          | INT             | 58    | 18
# 647    | ,          | COMMA           | 58    | 19
# 648    | 1          | INT             | 58    | 20
# 649    | )          | RPAREN          | 58    | 21
# 650    | )          | RPAREN          | 58    | 22
# 651    | op2        | IDENTIFIER      | 59    | 4
# 652    | =          | ASSIGN          | 59    | 8
# 653    | 1          | INT             | 59    | 10
# 654    | /          | DIV             | 59    | 11
# 655    | 2          | INT             | 59    | 12
# 656    | *          | MUL             | 59    | 14
# 657    | (          | LPAREN          | 59    | 16
# 658    | (          | LPAREN          | 59    | 17
# 659    | 1i         | COMPLEX         | 59    | 18
# 660    | ,          | COMMA           | 59    | 20
# 661    | 1i         | COMPLEX         | 59    | 21
# 662    | )          | RPAREN          | 59    | 23
# 663    | ,          | COMMA           | 59    | 24
# 664    | (          | LPAREN          | 59    | 26
# 665    | 1i         | COMPLEX         | 59    | 27
# 666    | ,          | COMMA           | 59    | 29
# 667    | 1i         | COMPLEX         | 59    | 30
# 668    | )          | RPAREN          | 59    | 32
# 669    | )          | RPAREN          | 59    | 33
# 670    | |ket0>     | KET_IDENTIFIER  | 60    | 4
# 671    | =          | ASSIGN          | 60    | 11
# 672    | (          | LPAREN          | 60    | 13
# 673    | 1          | INT             | 60    | 14
# 674    | ,          | COMMA           | 60    | 15
# 675    | 0          | INT             | 60    | 16
# 676    | )          | RPAREN          | 60    | 17
# 677    | |ket1>     | KET_IDENTIFIER  | 61    | 4
# 678    | =          | ASSIGN          | 61    | 11
# 679    | (          | LPAREN          | 61    | 13
# 680    | 0          | INT             | 61    | 14
# 681    | ,          | COMMA           | 61    | 15
# 682    | 1          | INT             | 61    | 16
# 683    | )          | RPAREN          | 61    | 17
# 684    | op         | IDENTIFIER      | 62    | 4
# 685    | =          | ASSIGN          | 62    | 7
# 686    | (          | LPAREN          | 62    | 9
# 687    | (          | LPAREN          | 62    | 10
# 688    | 1          | INT             | 62    | 11
# 689    | ,          | COMMA           | 62    | 12
# 690    | 0          | INT             | 62    | 13
# 691    | )          | RPAREN          | 62    | 14
# 692    | ,          | COMMA           | 62    | 15
# 693    | (          | LPAREN          | 62    | 17
# 694    | 0          | INT             | 62    | 18
# 695    | ,          | COMMA           | 62    | 19
# 696    | 1          | INT             | 62    | 20
# 697    | )          | RPAREN          | 62    | 21
# 698    | )          | RPAREN          | 62    | 22
# 699    | op2        | IDENTIFIER      | 63    | 4
# 700    | =          | ASSIGN          | 63    | 8
# 701    | 1          | INT             | 63    | 10
# 702    | /          | DIV             | 63    | 11
# 703    | 2          | INT             | 63    | 12
# 704    | *          | MUL             | 63    | 14
# 705    | (          | LPAREN          | 63    | 16
# 706    | (          | LPAREN          | 63    | 17
# 707    | 1i         | COMPLEX         | 63    | 18
# 708    | ,          | COMMA           | 63    | 20
# 709    | 1i         | COMPLEX         | 63    | 21
# 710    | )          | RPAREN          | 63    | 23
# 711    | ,          | COMMA           | 63    | 24
# 712    | (          | LPAREN          | 63    | 26
# 713    | 1i         | COMPLEX         | 63    | 27
# 714    | ,          | COMMA           | 63    | 29
# 715    | 1i         | COMPLEX         | 63    | 30
# 716    | )          | RPAREN          | 63    | 32
# 717    | )          | RPAREN          | 63    | 33
# 718    | |ket0>     | KET_IDENTIFIER  | 64    | 4
# 719    | =          | ASSIGN          | 64    | 11
# 720    | (          | LPAREN          | 64    | 13
# 721    | 1          | INT             | 64    | 14
# 722    | ,          | COMMA           | 64    | 15
# 723    | 0          | INT             | 64    | 16
# 724    | )          | RPAREN          | 64    | 17
# 725    | |ket1>     | KET_IDENTIFIER  | 65    | 4
# 726    | =          | ASSIGN          | 65    | 11
# 727    | (          | LPAREN          | 65    | 13
# 728    | 0          | INT             | 65    | 14
# 729    | ,          | COMMA           | 65    | 15
# 730    | 1          | INT             | 65    | 16
# 731    | )          | RPAREN          | 65    | 17
# 732    | op         | IDENTIFIER      | 66    | 4
# 733    | =          | ASSIGN          | 66    | 7
# 734    | (          | LPAREN          | 66    | 9
# 735    | (          | LPAREN          | 66    | 10
# 736    | 1          | INT             | 66    | 11
# 737    | ,          | COMMA           | 66    | 12
# 738    | 0          | INT             | 66    | 13
# 739    | )          | RPAREN          | 66    | 14
# 740    | ,          | COMMA           | 66    | 15
# 741    | (          | LPAREN          | 66    | 17
# 742    | 0          | INT             | 66    | 18
# 743    | ,          | COMMA           | 66    | 19
# 744    | 1          | INT             | 66    | 20
# 745    | )          | RPAREN          | 66    | 21
# 746    | )          | RPAREN          | 66    | 22
# 747    | op2        | IDENTIFIER      | 67    | 4
# 748    | =          | ASSIGN          | 67    | 8
# 749    | 1          | INT             | 67    | 10
# 750    | /          | DIV             | 67    | 11
# 751    | 2          | INT             | 67    | 12
# 752    | *          | MUL             | 67    | 14
# 753    | (          | LPAREN          | 67    | 16
# 754    | (          | LPAREN          | 67    | 17
# 755    | 1i         | COMPLEX         | 67    | 18
# 756    | ,          | COMMA           | 67    | 20
# 757    | 1i         | COMPLEX         | 67    | 21
# 758    | )          | RPAREN          | 67    | 23
# 759    | ,          | COMMA           | 67    | 24
# 760    | (          | LPAREN          | 67    | 26
# 761    | 1i         | COMPLEX         | 67    | 27
# 762    | ,          | COMMA           | 67    | 29
# 763    | 1i         | COMPLEX         | 67    | 30
# 764    | )          | RPAREN          | 67    | 32
# 765    | )          | RPAREN          | 67    | 33
# 766    | |ket0>     | KET_IDENTIFIER  | 68    | 4
# 767    | =          | ASSIGN          | 68    | 11
# 768    | (          | LPAREN          | 68    | 13
# 769    | 1          | INT             | 68    | 14
# 770    | ,          | COMMA           | 68    | 15
# 771    | 0          | INT             | 68    | 16
# 772    | )          | RPAREN          | 68    | 17
# 773    | |ket1>     | KET_IDENTIFIER  | 69    | 4
# 774    | =          | ASSIGN          | 69    | 11
# 775    | (          | LPAREN          | 69    | 13
# 776    | 0          | INT             | 69    | 14
# 777    | ,          | COMMA           | 69    | 15
# 778    | 1          | INT             | 69    | 16
# 779    | )          | RPAREN          | 69    | 17
# 780    | op         | IDENTIFIER      | 70    | 4
# 781    | =          | ASSIGN          | 70    | 7
# 782    | (          | LPAREN          | 70    | 9
# 783    | (          | LPAREN          | 70    | 10
# 784    | 1          | INT             | 70    | 11
# 785    | ,          | COMMA           | 70    | 12
# 786    | 0          | INT             | 70    | 13
# 787    | )          | RPAREN          | 70    | 14
# 788    | ,          | COMMA           | 70    | 15
# 789    | (          | LPAREN          | 70    | 17
# 790    | 0          | INT             | 70    | 18
# 791    | ,          | COMMA           | 70    | 19
# 792    | 1          | INT             | 70    | 20
# 793    | )          | RPAREN          | 70    | 21
# 794    | )          | RPAREN          | 70    | 22
# 795    | op2        | IDENTIFIER      | 71    | 4
# 796    | =          | ASSIGN          | 71    | 8
# 797    | 1          | INT             | 71    | 10
# 798    | /          | DIV             | 71    | 11
# 799    | 2          | INT             | 71    | 12
# 800    | *          | MUL             | 71    | 14
# 801    | (          | LPAREN          | 71    | 16
# 802    | (          | LPAREN          | 71    | 17
# 803    | 1i         | COMPLEX         | 71    | 18
# 804    | ,          | COMMA           | 71    | 20
# 805    | 1i         | COMPLEX         | 71    | 21
# 806    | )          | RPAREN          | 71    | 23
# 807    | ,          | COMMA           | 71    | 24
# 808    | (          | LPAREN          | 71    | 26
# 809    | 1i         | COMPLEX         | 71    | 27
# 810    | ,          | COMMA           | 71    | 29
# 811    | 1i         | COMPLEX         | 71    | 30
# 812    | )          | RPAREN          | 71    | 32
# 813    | )          | RPAREN          | 71    | 33
# 814    | |ket0>     | KET_IDENTIFIER  | 72    | 4
# 815    | =          | ASSIGN          | 72    | 11
# 816    | (          | LPAREN          | 72    | 13
# 817    | 1          | INT             | 72    | 14
# 818    | ,          | COMMA           | 72    | 15
# 819    | 0          | INT             | 72    | 16
# 820    | )          | RPAREN          | 72    | 17
# 821    | |ket1>     | KET_IDENTIFIER  | 73    | 4
# 822    | =          | ASSIGN          | 73    | 11
# 823    | (          | LPAREN          | 73    | 13
# 824    | 0          | INT             | 73    | 14
# 825    | ,          | COMMA           | 73    | 15
# 826    | 1          | INT             | 73    | 16
# 827    | )          | RPAREN          | 73    | 17
# 828    | op         | IDENTIFIER      | 74    | 4
# 829    | =          | ASSIGN          | 74    | 7
# 830    | (          | LPAREN          | 74    | 9
# 831    | (          | LPAREN          | 74    | 10
# 832    | 1          | INT             | 74    | 11
# 833    | ,          | COMMA           | 74    | 12
# 834    | 0          | INT             | 74    | 13
# 835    | )          | RPAREN          | 74    | 14
# 836    | ,          | COMMA           | 74    | 15
# 837    | (          | LPAREN          | 74    | 17
# 838    | 0          | INT             | 74    | 18
# 839    | ,          | COMMA           | 74    | 19
# 840    | 1          | INT             | 74    | 20
# 841    | )          | RPAREN          | 74    | 21
# 842    | )          | RPAREN          | 74    | 22
# 843    | op2        | IDENTIFIER      | 75    | 4
# 844    | =          | ASSIGN          | 75    | 8
# 845    | 1          | INT             | 75    | 10
# 846    | /          | DIV             | 75    | 11
# 847    | 2          | INT             | 75    | 12
# 848    | *          | MUL             | 75    | 14
# 849    | (          | LPAREN          | 75    | 16
# 850    | (          | LPAREN          | 75    | 17
# 851    | 1i         | COMPLEX         | 75    | 18
# 852    | ,          | COMMA           | 75    | 20
# 853    | 1i         | COMPLEX         | 75    | 21
# 854    | )          | RPAREN          | 75    | 23
# 855    | ,          | COMMA           | 75    | 24
# 856    | (          | LPAREN          | 75    | 26
# 857    | 1i         | COMPLEX         | 75    | 27
# 858    | ,          | COMMA           | 75    | 29
# 859    | 1i         | COMPLEX         | 75    | 30
# 860    | )          | RPAREN          | 75    | 32
# 861    | )          | RPAREN          | 75    | 33
# 862    | |ket0>     | KET_IDENTIFIER  | 76    | 4
# 863    | =          | ASSIGN          | 76    | 11
# 864    | (          | LPAREN          | 76    | 13
# 865    | 1          | INT             | 76    | 14
# 866    | ,          | COMMA           | 76    | 15
# 867    | 0          | INT             | 76    | 16
# 868    | )          | RPAREN          | 76    | 17
# 869    | |ket1>     | KET_IDENTIFIER  | 77    | 4
# 870    | =          | ASSIGN          | 77    | 11
# 871    | (          | LPAREN          | 77    | 13
# 872    | 0          | INT             | 77    | 14
# 873    | ,          | COMMA           | 77    | 15
# 874    | 1          | INT             | 77    | 16
# 875    | )          | RPAREN          | 77    | 17
# 876    | op         | IDENTIFIER      | 78    | 4
# 877    | =          | ASSIGN          | 78    | 7
# 878    | (          | LPAREN          | 78    | 9
# 879    | (          | LPAREN          | 78    | 10
# 880    | 1          | INT             | 78    | 11
# 881    | ,          | COMMA           | 78    | 12
# 882    | 0          | INT             | 78    | 13
# 883    | )          | RPAREN          | 78    | 14
# 884    | ,          | COMMA           | 78    | 15
# 885    | (          | LPAREN          | 78    | 17
# 886    | 0          | INT             | 78    | 18
# 887    | ,          | COMMA           | 78    | 19
# 888    | 1          | INT             | 78    | 20
# 889    | )          | RPAREN          | 78    | 21
# 890    | )          | RPAREN          | 78    | 22
# 891    | op2        | IDENTIFIER      | 79    | 4
# 892    | =          | ASSIGN          | 79    | 8
# 893    | 1          | INT             | 79    | 10
# 894    | /          | DIV             | 79    | 11
# 895    | 2          | INT             | 79    | 12
# 896    | *          | MUL             | 79    | 14
# 897    | (          | LPAREN          | 79    | 16
# 898    | (          | LPAREN          | 79    | 17
# 899    | 1i         | COMPLEX         | 79    | 18
# 900    | ,          | COMMA           | 79    | 20
# 901    | 1i         | COMPLEX         | 79    | 21
# 902    | )          | RPAREN          | 79    | 23
# 903    | ,          | COMMA           | 79    | 24
# 904    | (          | LPAREN          | 79    | 26
# 905    | 1i         | COMPLEX         | 79    | 27
# 906    | ,          | COMMA           | 79    | 29
# 907    | 1i         | COMPLEX         | 79    | 30
# 908    | )          | RPAREN          | 79    | 32
# 909    | )          | RPAREN          | 79    | 33
# 910    | |ket0>     | KET_IDENTIFIER  | 80    | 4
# 911    | =          | ASSIGN          | 80    | 11
# 912    | (          | LPAREN          | 80    | 13
# 913    | 1          | INT             | 80    | 14
# 914    | ,          | COMMA           | 80    | 15
# 915    | 0          | INT             | 80    | 16
# 916    | )          | RPAREN          | 80    | 17
# 917    | |ket1>     | KET_IDENTIFIER  | 81    | 4
# 918    | =          | ASSIGN          | 81    | 11
# 919    | (          | LPAREN          | 81    | 13
# 920    | 0          | INT             | 81    | 14
# 921    | ,          | COMMA           | 81    | 15
# 922    | 1          | INT             | 81    | 16
# 923    | )          | RPAREN          | 81    | 17
# 924    | op         | IDENTIFIER      | 82    | 4
# 925    | =          | ASSIGN          | 82    | 7
# 926    | (          | LPAREN          | 82    | 9
# 927    | (          | LPAREN          | 82    | 10
# 928    | 1          | INT             | 82    | 11
# 929    | ,          | COMMA           | 82    | 12
# 930    | 0          | INT             | 82    | 13
# 931    | )          | RPAREN          | 82    | 14
# 932    | ,          | COMMA           | 82    | 15
# 933    | (          | LPAREN          | 82    | 17
# 934    | 0          | INT             | 82    | 18
# 935    | ,          | COMMA           | 82    | 19
# 936    | 1          | INT             | 82    | 20
# 937    | )          | RPAREN          | 82    | 21
# 938    | )          | RPAREN          | 82    | 22
# 939    | op2        | IDENTIFIER      | 83    | 4
# 940    | =          | ASSIGN          | 83    | 8
# 941    | 1          | INT             | 83    | 10
# 942    | /          | DIV             | 83    | 11
# 943    | 2          | INT             | 83    | 12
# 944    | *          | MUL             | 83    | 14
# 945    | (          | LPAREN          | 83    | 16
# 946    | (          | LPAREN          | 83    | 17
# 947    | 1i         | COMPLEX         | 83    | 18
# 948    | ,          | COMMA           | 83    | 20
# 949    | 1i         | COMPLEX         | 83    | 21
# 950    | )          | RPAREN          | 83    | 23
# 951    | ,          | COMMA           | 83    | 24
# 952    | (          | LPAREN          | 83    | 26
# 953    | 1i         | COMPLEX         | 83    | 27
# 954    | ,          | COMMA           | 83    | 29
# 955    | 1i         | COMPLEX         | 83    | 30
# 956    | )          | RPAREN          | 83    | 32
# 957    | )          | RPAREN          | 83    | 33
# 958    | return     | RETURN          | 84    | 4
# 959    | x          | IDENTIFIER      | 84    | 11
# 960    | }          | RCURLY          | 85    | 0
# 961    | <EOF>      | EOF             | 86    | 0
#
# --- Errors ---
# No errors.
# Execution time: 0.602817 seconds
